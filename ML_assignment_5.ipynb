# %%
1. What are the key tasks that machine learning entails? What does data pre-processing imply?

Machine learning helps to predict the outcome for any new data, that is shown to the system like forecasting company future sales
or house price predictions based on several factors , it simple means the machine has the ability to perform certain tasks 
without being explicitly programmed.
Pre-processing means to know more about the data given , like to know about missing or null values as they will affect the
accuracy of the ML algorithm , it also means to know the correlation between several features in dataset or duplicay.


2. Describe quantitative and qualitative data in depth. Make a distinction between the two.

Quantitaive data means numerical data which is present in numeric way but on other side quantitaive data means categorical data
which can be of ordinal, nominal, interval or in form of ratio basically the Rank of officers in UPSC comes under qualitative
data but their salaries will be quantitaive data.



3. Create a basic data collection that includes some sample records. Have at least one attribute from
each of the machine learning data types.

Determine What Information You Want to Collect:
    The first thing you need to do is choose what details you want to collect. You’ll need to decide what topics the information
    will cover, who you want to collect it from and how much data you need. Your goals — what you hope to accomplish using your
    data — will determine your answers to these questions. As an example, you may decide to collect data about which type of 
    articles are most popular on your website among visitors who are between the ages of 18 and 34. You might also choose to 
    gather information about the average age of all of the customers who bought a product from your company within the last 
    month.

Set a Timeframe for Data Collection: er the long term. If you’re tracking data for a specific campaign, however, you’ll track it over a defined period. In these instances, you’ll have a schedule for when you’ll start and end your data collection.

Determine Your Data Collection Method.



4. What are the various causes of machine learning data issues? What are the ramifications?

ML data issues can be because of outliers present in the dataset or sampling is not done or their is adta present in 
numerical+categorical form.

5. Demonstrate various approaches to categorical data exploration with appropriate examples.

Using --> sns.countplot and for numerical sns.heatmap(df.corr(),annot=True) - This displays the correlation between different types of the columns in dataset
using histogramto know about the frequency

# %%
6. How would the learning activity be affected if certain variables have missing values? Having said
that, what can be done about it?

The missing values will directly impact the accuracy of the algorithm supplie, it can be removed by using Simple imputer
with startegy mean or median or most frequent or KNN imputer can also be used.

7. Describe the various methods for dealing with missing data values in depth.

The missing values will directly impact the accuracy of the algorithm supplie, it can be removed by using Simple imputer
with startegy mean or median or most frequent or KNN imputer can also be used.

with startegy mean it will replce all missing values with the mean fo that column and when their are outliers you can use median 
Strategy="Most frequent" can also be used when theur are categorical variables to replce missing with most occuring value.

8. What are the various data pre-processing techniques? Explain dimensionality reduction and
function selection in a few words.

Feature selection simply means to take those features which are directly impacting the output column and ignoring all other.
It can be achieved using Lasso(L1 regularization) or by the knowledge of domain experts.

Dimesionality Reduction- It simply mean to reduce the dimesion of the data by simply converting them to PCA componenets
and then drawing screen plot showing how much data is covered when 2-3 or 4 PCA components are taken , if the 2, 3 or 4 PCA
components are able to cover 90 percent of the data then you dont have to take whole data.



9.

i. What is the IQR? What criteria are used to assess it?

Inter quartile range it simply means that the diffrence between q3 and q1 where q3 means the data which is greater than 75 % of 
the values in dataset and q1 means 25 
so the differnce between them .
q3,q1= np.percentile([75,25], data=df)

IQR= q3-q1

ii. Describe the various components of a box plot in detail? When will the lower whisker
surpass the upper whisker in length? How can box plots be used to identify outliers?

# %%
import seaborn as sns

# %%
minimum is the minimum value in the dataset
maximum is the maximum value in the dataset.
So the difference between the two tells us about the range of dataset.

The median is the median (or centre point), also called second quartile, of the data
(resulting from the fact that the data is ordered).

Q1 is the first quartile of the data, i.e., to say 25% of the data lies between minimum and Q1.
Q3 is the third quartile of the data, i.e., to say 75%

When the data is left skewed, lower whisker will be longer than upper whisker.

# %%
10. Make brief notes on any two of the following ?
Data collected at regular intervals

The gap between the quartiles

Q1 is the first quartile of the data, i.e., to say 25% of the data lies between minimum and Q1.
Q3 is the third quartile of the data, i.e., to say 75%

Use a cross-tab
it shows the relationship between 2 or more variables.

# %%
 Make a comparison between ?
Data with nominal and ordinal values
Histogram and box plot
The average and median
Ans: The following are the breif notes about:

The average and median:

The mean (informally, the “average“) is found by adding all of the numbers together and dividing by the number of items in the set: 10 + 10 + 20 + 40 + 70 / 5 = 30. The median is found by ordering the set from lowest to highest and finding the exact middle. The median is just the middle number: 20
Histogram and barplot:

Histograms and box plots are very similar in that they both help to visualize and describe numeric data. Although histograms are better in determining the underlying distribution of the data, box plots allow you to compare multiple data sets better than histograms as they are less detailed and take up less space.
